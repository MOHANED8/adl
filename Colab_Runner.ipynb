# %% [markdown]
# # Early Overfitting Diagnostic System (Colab Runner)
# Welcome to the Google Colab environment for your project. This notebook will automatically clone your GitHub repository, install all necessary dependencies, and execute the full unified test suite using Colab's free GPUs.
#
# **Before running the cells, go to Runtime > Change runtime type in the top menu, select T4 GPU (or any available GPU), and click Save.**

# %%
# !git clone https://github.com/MOHANED8/adl.git
# %cd adl
# !pip install -r requirements.txt

# %%
# !python test_suite.py

# %%
# !python run_experiments.py
